# %%
import random
from collections import defaultdict

# %%
text = """
machine learning is fun
machine learning is powerful
learning machine models is interesting
machine intelligence is growing
"""

# %%
words = text.lower().split()

markov_chain = defaultdict(list)

for i in range(len(words) - 1):
    current_word = words[i]
    next_word = words[i + 1]
    markov_chain[current_word].append(next_word)

# %%
def generate_text(start_word, length=20):
    current_word = start_word.lower()
    generated_words = [current_word]

    for _ in range(length - 1):
        next_words = markov_chain.get(current_word)
        if not next_words:
            break
        current_word = random.choice(next_words)
        generated_words.append(current_word)

    return " ".join(generated_words)

# %%
print(generate_text("machine", 15))
# Out:
# machine learning is growing

# %%
print(generate_text("learning", 15))
# Out:
# learning machine intelligence is growing
